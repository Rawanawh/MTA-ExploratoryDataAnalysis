# %%
import pandas as pd

# %%
df_movies= pd.read_json('imdb_movies_dataframe.json')

# %%
df_movies
# Out:
#       index                                         name  year certificate  \
# 0         1                     The Shawshank Redemption  1994           R
# 1         2                              The Dark Knight  2008       PG-13
# 2         3                                    Inception  2010       PG-13
# 3         4                                   Fight Club  1999           R
# 4         5                                 Pulp Fiction  1994           R
# ...     ...                                          ...   ...         ...
# 1245  1,246                                    Road Trip  2000           R
# 1246  1,247                        Terminator: Dark Fate  2019           R
# 1247  1,248  Miss Peregrine's Home for Peculiar Children  2016       PG-13
# 1248  1,249                                  King Arthur  2004       PG-13
# 1249  1,250                                    Evil Dead  2013           R
#
#       runtime_in_min                          genre  rating  \
# ...

# %%
df_movies.isnull().sum()
# Out:
# index                42
# name                 42
# year                 42
# certificate          42
# runtime_in_min       42
# genre                42
# rating               42
# ratings_metascore    42
# vote                 42
# gross                42
# dtype: int64

# %%
df_movies.dropna( inplace= True)

# %%
df_movies.isnull().sum()
# Out:
# index                0
# name                 0
# year                 0
# certificate          0
# runtime_in_min       0
# genre                0
# rating               0
# ratings_metascore    0
# vote                 0
# gross                0
# dtype: int64

# %%
df_movies
# Out:
#       index                                         name  year certificate  \
# 0         1                     The Shawshank Redemption  1994           R
# 1         2                              The Dark Knight  2008       PG-13
# 2         3                                    Inception  2010       PG-13
# 3         4                                   Fight Club  1999           R
# 4         5                                 Pulp Fiction  1994           R
# ...     ...                                          ...   ...         ...
# 1245  1,246                                    Road Trip  2000           R
# 1246  1,247                        Terminator: Dark Fate  2019           R
# 1247  1,248  Miss Peregrine's Home for Peculiar Children  2016       PG-13
# 1248  1,249                                  King Arthur  2004       PG-13
# 1249  1,250                                    Evil Dead  2013           R
#
#       runtime_in_min                          genre  rating  \
# ...

# %%
df_movies.set_index('index', inplace=True)

# %%
df_movies
# Out:
#                                               name  year certificate  \
# index
# 1                         The Shawshank Redemption  1994           R
# 2                                  The Dark Knight  2008       PG-13
# 3                                        Inception  2010       PG-13
# 4                                       Fight Club  1999           R
# 5                                     Pulp Fiction  1994           R
# ...                                            ...   ...         ...
# 1,246                                    Road Trip  2000           R
# 1,247                        Terminator: Dark Fate  2019           R
# 1,248  Miss Peregrine's Home for Peculiar Children  2016       PG-13
# 1,249                                  King Arthur  2004       PG-13
# 1,250                                    Evil Dead  2013           R
#
#        runtime_in_min                          genre  rating  \
# index
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1250 entries, 0 to 1249
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              1208 non-null   object
#  1   name               1208 non-null   object
#  2   year               1208 non-null   float64
#  3   certificate        1208 non-null   object
#  4   runtime_in_min     1208 non-null   float64
#  5   genre              1208 non-null   object
#  6   rating             1208 non-null   float64
#  7   ratings_metascore  1208 non-null   float64
#  8   vote               1208 non-null   float64
#  9   gross              1208 non-null   float64
# dtypes: float64(6), object(4)
# memory usage: 139.7+ KB

# %%
df_movies['year'] = df_movies.year.str.strip('Ii ) ( Xx')

# %%
df_movies['year'] = df_movies['year'].apply(pd.to_numeric)

# %%
df_movies[['rating','ratings_metascore','vote','gross']].describe()
# Out:
#             rating  ratings_metascore          vote         gross
# count  1208.000000        1208.000000  1.208000e+03  1.208000e+03
# mean      7.243626          65.356788  3.819653e+05  1.183887e+08
# std       0.757646          16.038562  2.780275e+05  1.122370e+08
# min       3.800000          23.000000  1.632530e+05  3.600000e+03
# 25%       6.700000          54.000000  2.103860e+05  4.303701e+07
# 50%       7.300000          66.000000  2.816090e+05  8.665000e+07
# 75%       7.800000          77.000000  4.420810e+05  1.628003e+08
# max       9.300000         100.000000  2.473258e+06  9.366622e+08

# %%
import seaborn as sns

# %%
sns.pairplot(df_movies)

# %%
sns.heatmap(df_movies.corr(), annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
sns.regplot(data= df_movies, x='ratings_metascore', y='vote')
# Out:
# <AxesSubplot:xlabel='ratings_metascore', ylabel='vote'>

# %%
sns.regplot(data= df_movies, x='rating', y='vote')
# Out:
# <AxesSubplot:xlabel='rating', ylabel='vote'>

# %%
sns.regplot(data= df_movies, x='rating_squared', y='vote')
# Out:
# <AxesSubplot:xlabel='rating_squared', ylabel='vote'>

# %%
sns.boxplot(data= movies, orient='h',palette='Set2')
# Out:
# <AxesSubplot:>

# %%
movies = df_movies[['rating_squared','ratings_metascore','rating','vote']]

# %%
movies
# Out:
#       rating_squared  ratings_metascore  rating       vote
# 0              86.49               80.0     9.3  2473258.0
# 1              81.00               84.0     9.0  2427277.0
# 2              77.44               74.0     8.8  2178023.0
# 3              77.44               66.0     8.8  1947366.0
# 4              79.21               94.0     8.9  1914649.0
# ...              ...                ...     ...        ...
# 1245           40.96               55.0     6.4   163565.0
# 1246           38.44               54.0     6.2   163493.0
# 1247           44.89               57.0     6.7   163366.0
# 1248           39.69               46.0     6.3   163332.0
# 1249           42.25               57.0     6.5   163253.0
#
# [1250 rows x 4 columns]

# %%
import numpy as np

# %%
median = movies.loc[movies['vote']<1500000, 'vote'].median()
movies.loc[movies.vote > 1500000, 'vote'] = np.nan
movies.fillna(median,inplace=True)
# Out:
# /Users/rawanawad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/rawanawad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# /Users/rawanawad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df2= movies['vote']

# %%
df2.describe()
# Out:
# count      1250.000000
# mean     232096.436690
# std       35544.442302
# min      163253.000000
# 25%      212143.250000
# 50%      232096.436690
# 75%      243581.250000
# max      299517.000000
# Name: vote, dtype: float64

# %%
sns.displot(data=df2,bins= 5, kde=True)

# %%
df_movies.columns
# Out:
# Index(['index', 'name', 'year', 'certificate', 'runtime_in_min', 'genre',
#        'rating', 'ratings_metascore', 'vote', 'gross', 'rating_squared'],
#       dtype='object')

# %%
sns.regplot(data= df_movies, x='ratings_metascore', y='rating')
# Out:
# <AxesSubplot:xlabel='ratings_metascore', ylabel='rating'>

# %%
import matplotlib as plt
df_movies.set_index('year')['vote'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df_movies['rating_squared']= df_movies['rating']**2

# %%
df_movies
# Out:
#       index                                         name    year certificate  \
# 0         1                     The Shawshank Redemption  1994.0           R
# 1         2                              The Dark Knight  2008.0       PG-13
# 2         3                                    Inception  2010.0       PG-13
# 3         4                                   Fight Club  1999.0           R
# 4         5                                 Pulp Fiction  1994.0           R
# ...     ...                                          ...     ...         ...
# 1245  1,246                                    Road Trip  2000.0           R
# 1246  1,247                        Terminator: Dark Fate  2019.0           R
# 1247  1,248  Miss Peregrine's Home for Peculiar Children  2016.0       PG-13
# 1248  1,249                                  King Arthur  2004.0       PG-13
# 1249  1,250                                    Evil Dead  2013.0           R
#
# ...
